# %% [markdown]
# ### **Name: Manuj Kumar Joshi**

# %% [markdown]
# ### **Status : Intern**

# %% [markdown]
# ### **Organisation : The Sparks Foundation**

# %% [markdown]
# ### **Task 3 : Exploratory Data Analysis**

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#      Question : As a business manager, try to find out the weak areas where you can
# work to make more profit
# </div>

# %% [markdown]
# <h3> Step 1 : Import Libraries</h3>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <h3> Step 2 : Load the dataset</h3>

# %%
df=pd.read_csv('SampleSuperstore.csv')
df.sample(5)
# Out:
#            Ship Mode      Segment        Country           City       State  \
# 7981     First Class     Consumer  United States        Clifton  New Jersey
# 965      First Class  Home Office  United States  New York City    New York
# 3988  Standard Class    Corporate  United States       Columbia   Tennessee
# 4911  Standard Class     Consumer  United States   Johnson City   Tennessee
# 9661  Standard Class  Home Office  United States  Santa Barbara  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 7981         7011   East  Office Supplies   Appliances   81.920         4
# 965         10011   East  Office Supplies          Art   35.970         3
# 3988        38401  South        Furniture  Furnishings   79.120         5
# 4911        37604  South       Technology       Phones  111.984         2
# 9661        93101   West       Technology  Accessories   26.960         2
#
#       Discount   Profit
# 7981       0.0  22.1184
# ...

# %% [markdown]
# <h3> Step 3 : Analyze the Data</h3>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df=df.drop(['Postal Code'],axis=1)  # dropped Postal Code Column

# %%
df.shape
# Out:
# (9994, 12)

# %%
df.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
df['City'].nunique()
# Out:
# 531

# %% [markdown]
# <h3> Step 4 : Category and subcategory wise data summary</h3>

# %%
df.groupby(['Category','Sub-Category']).sum()
# Out:
#                                     Sales  Quantity  Discount      Profit
# Category        Sub-Category
# Furniture       Bookcases     114879.9963       868     48.14  -3472.5560
#                 Chairs        328449.1030      2356    105.00  26590.1663
#                 Furnishings    91705.1640      3563    132.40  13059.1436
#                 Tables        206965.5320      1241     83.35 -17725.4811
# Office Supplies Appliances    107532.1610      1729     77.60  18138.0054
#                 Art            27118.7920      3000     59.60   6527.7870
#                 Binders       203412.7330      5974    567.00  30221.7633
#                 Envelopes      16476.4020       906     20.40   6964.1767
#                 Fasteners       3024.2800       914     17.80    949.5182
#                 Labels         12486.3120      1400     25.00   5546.2540
#                 Paper          78479.2060      5178    102.60  34053.5693
# ...

# %% [markdown]
# <h3> Step 5 : Region and Category wise data summary</h3>

# %%
df.groupby(['Region','Category']).sum()
# Out:
#                                Sales  Quantity  Discount      Profit
# Region  Category
# Central Furniture        163797.1638      1827    143.04  -2871.0494
#         Office Supplies  167026.4150      5409    359.40   8879.9799
#         Technology       170416.3120      1544     55.90  33697.4320
# East    Furniture        208291.2040      2214     92.60   3046.1658
#         Office Supplies  205516.0550      6462    244.70  41014.5791
#         Technology       264973.9810      1942     76.70  47462.0351
# South   Furniture        117298.6840      1291     40.35   6771.2061
#         Office Supplies  125651.3130      3800    166.60  19986.3928
#         Technology       148771.9080      1118     31.60  19991.8314
# West    Furniture        252612.7435      2696     92.90  11504.9503
#         Office Supplies  220853.2490      7235    177.10  52609.8490
#         Technology       251991.8320      2335     80.20  44303.6496

# %% [markdown]
# <h3>Step 6 : Let's draw some plot to see the relationship between variables</h3>

# %% [markdown]
# <h3>Discount vs Sale</h3>

# %%
sns.regplot('Discount','Sales',data=df)  
df[['Discount','Sales']].corr()  # Discount do not have any effect on Sales so we should not give discounts
# Out:
#           Discount    Sales
# Discount   1.00000 -0.02819
# Sales     -0.02819  1.00000

# %% [markdown]
# <h3>Discount vs Profit</h3>

# %%
sns.regplot('Discount','Profit',data=df)
df[['Discount','Profit']].corr()   #Discount is not helping anywhere to make profit, hence failing to lure customers and somewhere making a negative effect.
# Out:
#           Discount    Profit
# Discount  1.000000 -0.219487
# Profit   -0.219487  1.000000

# %% [markdown]
# <h3>Sales vs Profit</h3>

# %%
sns.regplot('Sales','Profit',data=df)  
df[['Sales','Profit']].corr()  # Discount do not have any effect on Sales so we should not give discounts
# Out:
#            Sales    Profit
# Sales   1.000000  0.479064
# Profit  0.479064  1.000000

# %% [markdown]
# <h3>Lets Check the Summary according to Regions</h3>

# %%
df_region=df.groupby(['Region']).sum()  # West and East are Performing well, can be due to costal 
                                        # regions because gernally big cities are found at costal regions so region can 
                                        # be a natual benefit
df_region                               # So lets see independently the states that are in West n East
# Out:
#                Sales  Quantity  Discount       Profit
# Region
# Central  501239.8908      8780    558.34   39706.3625
# East     678781.2400     10618    414.00   91522.7800
# South    391721.9050      6209    238.55   46749.4303
# West     725457.8245     12266    350.20  108418.4489

# %% [markdown]
# <h3>Let's have a region wise Summary</h3>

# %% [markdown]
# <h3>West</h3>

# %%
region_wise=pd.DataFrame(df.groupby(['Region','State']).sum())
sorted=region_wise.sort_values(by='Sales')
pd.DataFrame(sorted.loc[['West'],['Sales','Profit','Discount']])
# Out:
#                          Sales      Profit  Discount
# Region State
# West   Wyoming       1603.1360    100.1960       0.2
#        Idaho         4382.4860    826.7231       1.8
#        New Mexico    4783.5220   1157.1161       2.2
#        Montana       5589.3520   1833.3285       1.0
#        Utah         11220.0560   2546.5335       3.2
#        Nevada       16729.1020   3316.7659       2.4
#        Oregon       17431.1500  -1190.4705      35.8
#        Colorado     32108.1180  -6527.8579      57.6
#        Arizona      35282.0010  -3427.9246      68.0
#        Washington  138641.2700  33402.6517      32.4
#        California  457687.6315  76381.3871     145.6

# %% [markdown]
# <h3>East</h3>

# %%
region_wise=pd.DataFrame(df.groupby(['Region','State']).sum())
sorted=region_wise.sort_values(by='Sales')
pd.DataFrame(sorted.loc[['East'],['Sales','Profit','Discount']])
# Out:
#                                   Sales      Profit  Discount
# Region State
# East   West Virginia           1209.824    185.9216       0.3
#        Maine                   1270.530    454.4862       0.0
#        District of Columbia    2865.020   1059.5893       0.0
#        New Hampshire           7292.524   1706.5028       0.3
#        Vermont                 8929.370   2244.9783       0.0
#        Connecticut            13384.357   3511.4918       0.6
#        Rhode Island           22627.956   7285.6293       1.2
#        Maryland               23705.523   7031.1788       0.6
#        Delaware               27451.069   9977.3748       0.6
#        Massachusetts          28634.434   6785.5016       2.1
#        New Jersey             35764.312   9772.9138       0.6
#        Ohio                   78258.136 -16971.3766     152.4
#        Pennsylvania          116511.914 -15559.9603     192.9
#        New York              310876.271  74038.5486      62.4

# %% [markdown]
# <h3>From this we can say more discount leads to more sales in East and West, Ohio and Pennsylvania are exception whose more Sales do not leads to more profit, Special monitoring is to be given to these two states to increase Sales</h3>

# %% [markdown]
# <h3>Ohio</h3>

# %%
region_wise=pd.DataFrame(df.groupby(['State','City']).sum())
sort=region_wise.sort_values(by='Profit')
Ohio=pd.DataFrame(sort.loc[['Ohio'],['Sales','Profit','Discount','Quantity']])
Ohio.head()
# Out:
#                       Sales     Profit  Discount  Quantity
# State City
# Ohio  Lancaster    8202.625 -7149.6180       9.7       121
#       Newark       8128.069 -2292.4127       9.8       137
#       Springfield  5613.167 -1420.1620      12.2       137
#       Medina       2477.722 -1343.0446       3.9        38
#       Troy         3180.535  -874.5873       6.0        55

# %% [markdown]
# <h3>Pennysylvania</h3>

# %%
region_wise=pd.DataFrame(df.groupby(['State','City']).sum())
sorta=region_wise.sort_values(by='Profit')
Penny=pd.DataFrame(sorta.loc[['Pennsylvania'],['Sales','Profit','Discount','Quantity']])
Penny.head()
# Out:
#                                 Sales      Profit  Discount  Quantity
# State        City
# Pennsylvania Philadelphia  109077.013 -13837.7674     175.5      1981
#              Bethlehem       1689.634  -1003.0958       1.9        18
#              Reading          873.712   -268.7642       1.3        16
#              Allentown        853.252   -226.4504       1.9        20
#              Lancaster       1211.395   -168.8876       4.0        35

# %% [markdown]
# <h3>So I got 2 worst performing States of Eastern USA, which is a big reason to worry for business according to stats</h3>

# %% [markdown]
# <h3>Solution -> You can Target Ohio's local festivals and can offer customers a bonanza to lure them to buy your goods
#
# Examples ->
# Ashville Viking Festival, Dandelion May Festival, Moonshine Festival, Troy Strawberry Festival, Banana Split Festival, Columbus Arts Festival

# %% [markdown]
# <h3>Solution -> You can Target Pennysylvania's local festivals and can offer customers a bonanza to lure them to buy your goods
#
# Examples -> Kutztown Folk Festival, The Firebird Festival, The Odunde Festival, Pennsylvania Firefly Festival</h3>

# %% [markdown]
# <h3>South</h3>

# %%
region_wise=pd.DataFrame(df.groupby(['Region','State']).sum())
sorted=region_wise.sort_values(by='Sales')
pd.DataFrame(sorted.loc[['South'],['Sales','Profit','Discount']])
# Out:
#                            Sales      Profit  Discount
# Region State
# South  South Carolina   8481.710   1769.0566      0.00
#        Louisiana        9217.030   2196.1023      0.00
#        Mississippi     10771.340   3172.9762      0.00
#        Arkansas        11678.130   4008.6871      0.00
#        Alabama         19510.640   5786.8253      0.00
#        Tennessee       30661.873  -5341.6936     53.30
#        Kentucky        36591.750  11199.6966      0.00
#        Georgia         49095.840  16250.0433      0.00
#        North Carolina  55603.164  -7490.9122     70.60
#        Virginia        70636.720  18597.9504      0.00
#        Florida         89473.708  -3399.3017    114.65

# %% [markdown]
# <h3>Central</h3>

# %%
region_wise=pd.DataFrame(df.groupby(['Region','State']).sum())
sorted=region_wise.sort_values(by='Sales')
pd.DataFrame(sorted.loc[['Central'],['Sales','Profit','Discount']])
# Out:
#                             Sales      Profit  Discount
# Region  State
# Central North Dakota     919.9100    230.1497      0.00
#         South Dakota    1315.5600    394.8283      0.00
#         Kansas          2914.3100    836.4435      0.00
#         Iowa            4579.7600   1183.8119      0.00
#         Nebraska        7464.9300   2037.0942      0.00
#         Oklahoma       19683.3900   4853.9560      0.00
#         Missouri       22205.1500   6436.2105      0.00
#         Minnesota      29863.1500  10823.1874      0.00
#         Wisconsin      32114.6100   8401.8004      0.00
#         Indiana        53555.3600  18382.9363      0.00
#         Michigan       76269.6140  24463.1876      1.80
#         Illinois       80166.1010 -12607.8870    191.90
#         Texas         170188.0458 -25729.3563    364.64

# %% [markdown]
# <h3>From this we can say discount have no effect on sales in South and Central but for Texas and Illinois Discount leads to loss so we should stop giving discounts here</h3>

# %% [markdown]
# <h3> Texas</h3>

# %%
region_wise=pd.DataFrame(df.groupby(['State','City']).sum())
sor=region_wise.sort_values(by='Profit')
Tex=pd.DataFrame(sorta.loc[['Texas'],['Sales','Profit','Discount','Quantity']])
Tex.head()
# Out:
#                         Sales      Profit  Discount  Quantity
# State City
# Texas Houston      64504.7604 -10153.5485    143.14      1466
#       San Antonio  21843.5280  -7299.0502     22.60       247
#       Dallas       20131.9322  -2846.5257     56.30       555
#       Round Rock    4854.0528  -1183.4313      1.92        23
#       Huntsville    6710.6168   -843.4264     10.62       121

# %% [markdown]
# <h3>Illinois</h3>

# %%
region_wise=pd.DataFrame(df.groupby(['State','City']).sum())
sor=region_wise.sort_values(by='Profit')
Ill=pd.DataFrame(sorta.loc[['Illinois'],['Sales','Profit','Discount','Quantity']])
Ill.head()
# Out:
#                           Sales     Profit  Discount  Quantity
# State    City
# Illinois Chicago      48539.541 -6654.5688     120.5      1132
#          Aurora        7572.968 -1894.7196      13.4       128
#          Rockford      3166.228 -1149.5078       5.6        64
#          Oswego         321.978  -536.1276       1.8        13
#          Bloomington    963.940  -432.1283       2.9        27

# %% [markdown]
# <h3>North Carolina</h3>

# %%
region_wise=pd.DataFrame(df.groupby(['State','City']).sum())
sor=region_wise.sort_values(by='Profit')
nc=pd.DataFrame(sorta.loc[['North Carolina'],['Sales','Profit','Discount','Quantity']])
nc.head()
# Out:
#                                Sales     Profit  Discount  Quantity
# State          City
# North Carolina Burlington  12681.282 -5894.5269       3.4        46
#                Concord      5111.844 -1788.6868       1.8        44
#                Greenville   2117.830  -548.9884       2.6        27
#                Charlotte   13693.339  -429.7824      15.3       243
#                Greensboro   2406.780  -122.9534       4.8        50

# %% [markdown]
# <h3>So I got 2 worst Performing States in Central USA, hopefully it is performing against the intrest because heavy discounts are given here which leads to a drop in profit, So My suggestion is to drop the discounts from here.</h3>

# %% [markdown]
# <h3>Category vs Region</h3>

# %%
df_region=df.groupby(['Region','Category']).sum()
df_region
# Out:
#                                Sales  Quantity  Discount      Profit
# Region  Category
# Central Furniture        163797.1638      1827    143.04  -2871.0494
#         Office Supplies  167026.4150      5409    359.40   8879.9799
#         Technology       170416.3120      1544     55.90  33697.4320
# East    Furniture        208291.2040      2214     92.60   3046.1658
#         Office Supplies  205516.0550      6462    244.70  41014.5791
#         Technology       264973.9810      1942     76.70  47462.0351
# South   Furniture        117298.6840      1291     40.35   6771.2061
#         Office Supplies  125651.3130      3800    166.60  19986.3928
#         Technology       148771.9080      1118     31.60  19991.8314
# West    Furniture        252612.7435      2696     92.90  11504.9503
#         Office Supplies  220853.2490      7235    177.10  52609.8490
#         Technology       251991.8320      2335     80.20  44303.6496

# %%
df['Category'].value_counts().idxmax()
# Out:
# 'Office Supplies'

# %%
df['Sub-Category'].value_counts().idxmax()
# Out:
# 'Binders'

# %% [markdown]
# <h3>Conclusions :</h3>

# %% [markdown]
# <h3>Due to Costal Region or being a port city the chances for having a purchase as business assets is more in Costal Region and is evident from the stats and it's a benefit by location, so for growth of sales in South and Central we have to do think about some offers to lure customers.

# %% [markdown]
# <h3>From this we can say more discount leads to more sales in East and West, Ohio and Pennsylvania are exception whose more Sales do not leads to more profit, Special monitoring is to be given to these two states to increase Sales</h3>

# %% [markdown]
# <h3>From this we can say discount have no effect on sales in South and Central but Texas, Illinois,Florida and North Carolin need extra monitoring to increase Sales </h3>

# %% [markdown]
# <h3>Thank you</h3>
